# %%
# import requests
# import json
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns


import pokemon

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 team_df(3, 10)
#
# Cell In[2], line 68, in team_df(p1, p2, p3, p4, p5, p6)
#      66 id_list = [p1, p2, p3, p4, p5, p6]
#      67 for i in id_list:
# ---> 68     team_list.append(get_stats(i))
#      70 col = ['dex_id', 'name', 'type', 'type_2', 'hp', 'attack', 'defense', 'sp_atk', 'sp_def', 'speed']
#      71 team_df = pd.DataFrame(data=team_list, columns = col)
#
# Cell In[2], line 20, in get_stats(pokemon)
#      14 def get_stats(pokemon):
#      16     '''
#      17     Takes a pokemon dex ID and calls the api. Then returns stats in a list
#      18     '''
# ---> 20     poke_stats = call_api(pokemon)
#      22     dex_id = pokemon
#      23     name = poke_stats['name']
#
# Cell In[2], line 8, in call_api(pokemon)
#       3 def call_api (pokemon):
#       4
# ...

# %%
generation_df(12,34)
# Out:
#     dex_id        name      type  type_2  hp  attack  defense  sp_atk  sp_def  \
# 0       12  butterfree       bug  flying  60      45       50      90      80
# 1       13      weedle       bug  poison  40      35       30      20      20
# 2       14      kakuna       bug  poison  45      25       50      25      25
# 3       15    beedrill       bug  poison  65      90       40      45      80
# 4       16      pidgey    normal  flying  40      45       40      35      35
# 5       17   pidgeotto    normal  flying  63      60       55      50      50
# 6       18     pidgeot    normal  flying  83      80       75      70      70
# 7       19     rattata    normal     N/A  30      56       35      25      35
# 8       20    raticate    normal     N/A  55      81       60      50      70
# 9       21     spearow    normal  flying  40      60       30      31      31
# 10      22      fearow    normal  flying  65      90       65      61      61
# ...
